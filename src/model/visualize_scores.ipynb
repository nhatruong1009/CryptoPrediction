# %%
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../../datastore/model_scores/grid_search_cv_5_len_2500.csv")

# %% [markdown]
# # 🔥 Test score

# %%
df.loc[df["mean_test_score"] > 0].plot(kind="bar", x="param_reg__estimator", y="mean_test_score", figsize=(15, 10))
fig = plt.figure()

# %% [markdown]
# # 🔥 Compare train and predict time

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 6))

ax1 = df.plot(kind="bar", x="rank_test_score", y="mean_fit_time", ax=axes[0])
ax1.set_ylabel("train time (s)")
ax2 = df.plot(kind="bar", x="rank_test_score", y="mean_score_time", ax=axes[1])
ax2.set_ylabel("predict time (s)")
# Out:
# Text(0, 0.5, 'predict time (s)')

# %%
pd.set_option('display.max_colwidth', None)
df[['rank_test_score','param_reg__estimator', 'mean_test_score', 'mean_fit_time', 'mean_score_time']]
# Out:
#     rank_test_score                           param_reg__estimator  \
# 0                 1  LinearRegressionEstimator(fit_intercept=True)
# 1                 1  LinearRegressionEstimator(fit_intercept=True)
# 2                 3                                 GRUEstimator()
# 3                 4                             SarimaxEstimator()
# 4                 5                             SarimaxEstimator()
# 5                 6                                 GRUEstimator()
# 6                 7                             SarimaxEstimator()
# 7                 8                             SarimaxEstimator()
# 8                 9                                 GRUEstimator()
# 9                10                                 GRUEstimator()
# 10               11                                 GRUEstimator()
# 11               12                                 GRUEstimator()
# 12               13                                 GRUEstimator()
# ...
