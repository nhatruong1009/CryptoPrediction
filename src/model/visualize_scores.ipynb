# %%
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../../datastore/model_scores/grid_search_cv_5_len_3000.csv")

# %% [markdown]
# # 🔥 Test score

# %%
df.loc[df["mean_test_score"] > 0].plot(kind="bar", x="param_reg__estimator", y="mean_test_score", figsize=(5, 10))
fig = plt.figure()

# %% [markdown]
# # 🔥 Compare train and predict time

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 6))

ax1 = df.plot(kind="bar", x="rank_test_score", y="mean_fit_time", ax=axes[0])
ax1.set_ylabel("train time (s)")
ax2 = df.plot(kind="bar", x="rank_test_score", y="mean_score_time", ax=axes[1])
ax2.set_ylabel("predict time (s)")
# Out:
# Text(0, 0.5, 'predict time (s)')

# %%
pd.set_option('display.max_colwidth', None)
df[['rank_test_score','param_reg__estimator', 'mean_test_score', 'mean_fit_time', 'mean_score_time']]
# Out:
#     rank_test_score                                param_reg__estimator  \
# 0                 1  GRUEstimator(batch_size=4, epochs=10, neurons=100)
# 1                 2  GRUEstimator(batch_size=4, epochs=10, neurons=100)
# 2                 3                         LinearRegressionEstimator()
# 3                 3                         LinearRegressionEstimator()
# 4                 5  GRUEstimator(batch_size=4, epochs=10, neurons=100)
# 5                 6  GRUEstimator(batch_size=4, epochs=10, neurons=100)
# 6                 7  GRUEstimator(batch_size=4, epochs=10, neurons=100)
# 7                 8  GRUEstimator(batch_size=4, epochs=10, neurons=100)
# 8                 9  GRUEstimator(batch_size=4, epochs=10, neurons=100)
# 9                10  GRUEstimator(batch_size=4, epochs=10, neurons=100)
# 10               11  GRUEstimator(batch_size=4, epochs=10, neurons=100)
# 11               12                                  SarimaxEstimator()
# 12               13  GRUEstimator(batch_size=4, epochs=10, neurons=100)
# 13               14                                  SarimaxEstimator()
# 14               15                                  SarimaxEstimator()
# 15               16  GRUEstimator(batch_size=4, epochs=10, neurons=100)
# 16               17  GRUEstimator(batch_size=4, epochs=10, neurons=100)
# 17               18  GRUEstimator(batch_size=4, epochs=10, neurons=100)
# 18               19                                  SarimaxEstimator()
# 19               20  GRUEstimator(batch_size=4, epochs=10, neurons=100)
# 20               21  GRUEstimator(batch_size=4, epochs=10, neurons=100)
# 21               22  GRUEstimator(batch_size=4, epochs=10, neurons=100)
# 22               23  GRUEstimator(batch_size=4, epochs=10, neurons=100)
# 23               24  GRUEstimator(batch_size=4, epochs=10, neurons=100)
# 24               25  GRUEstimator(batch_size=4, epochs=10, neurons=100)
# 25               26  GRUEstimator(batch_size=4, epochs=10, neurons=100)
# 26               27  GRUEstimator(batch_size=4, epochs=10, neurons=100)
# 27               28  GRUEstimator(batch_size=4, epochs=10, neurons=100)
# 28               29  GRUEstimator(batch_size=4, epochs=10, neurons=100)
# 29               30  GRUEstimator(batch_size=4, epochs=10, neurons=100)
# 30               31  GRUEstimator(batch_size=4, epochs=10, neurons=100)
# 31               32  GRUEstimator(batch_size=4, epochs=10, neurons=100)
# 32               33  GRUEstimator(batch_size=4, epochs=10, neurons=100)
#
#     mean_test_score  mean_fit_time  mean_score_time
# 0          0.842046      21.441244         0.445718
# 1          0.831308      32.442763         0.419484
# 2          0.826021       0.019346         0.000871
# 3          0.826021       0.026481         0.000839
# 4          0.815282      20.480924         0.304820
# 5          0.804522      16.568253         0.368986
# 6          0.803597      11.237536         0.324232
# 7          0.792218      12.861785         0.419696
# 8          0.777164       5.043652         0.343560
# 9          0.770298       9.734932         0.403287
# 10         0.766400       8.431334         0.463227
# 11         0.763469       0.001091       122.241994
# 12         0.756050       6.140342         0.380498
# 13         0.749743       0.000724       453.425023
# 14         0.748097       0.001257       135.128704
# 15         0.741347       4.974329         0.323019
# 16         0.730133       4.613902         0.395792
# 17         0.728974       7.544521         0.414756
# 18         0.728742       0.001383       518.631108
# 19         0.696784       5.694374         0.401290
# 20         0.668984       3.226295         0.477530
# 21         0.605942       3.722096         0.337094
# 22         0.556280      11.134016         0.308887
# 23         0.541587       7.084242         0.473498
# 24         0.408081       4.396022         0.343699
# 25         0.286989       3.373285         0.314563
# 26         0.169849       3.091662         0.300885
# 27        -1.005294       2.881144         0.455156
# 28        -1.713945       2.445910         0.342306
# 29        -2.426890       1.986262         0.347716
# 30        -3.195121       2.425539         0.338804
# 31        -6.018684       2.351018         0.453772
# 32        -8.004160       2.478926         0.334116
