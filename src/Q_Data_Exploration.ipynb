# %%
import pandas
from pandas import DataFrame
import numpy

# %% [markdown]
# Giải nghĩa các cột dữ liệu:
# * symbol : mã kí hiệu loại giao dịch
# * base : mã đồng cơ sở
# * quote : mã đồng báo giá
# * Kline open/close time : thời gian mở/đóng của việc thu dữ liệu
# * open price : Giá tại thời điểm đầu khi thu dữ liệu
# * close price : giá tại thời điểm cuối cùng khi thu dữ liệu
# * high price : giá cao nhất trong thời gian thu dữ liệu
# * low price : giá thấp nhất trong thời gian thu dữ liệu
# * volume : số lượng base đã được trao đổi
# * quote asset volume : số lượng quote đã được trao đổi
# * taker buy base volume : số lượng mua base (lệnh) (?)
# * taker buy quote volume : số lượng mua quote (lệnh) (?)

# %%
symbols = pandas.read_csv('symbols.csv').drop(['Unnamed: 0'], axis=1)
data = pandas.read_csv('data.csv').drop(['Unnamed: 0'], axis=1)

# %%
data
# Out:
#           Symbol  base quote  Kline open time  Open price  High price  \
# 0         ETHBTC   ETH   BTC    1669395600000    0.072026    0.072222
# 1         ETHBTC   ETH   BTC    1669397400000    0.072222    0.072335
# 2         ETHBTC   ETH   BTC    1669399200000    0.072163    0.072263
# 3         ETHBTC   ETH   BTC    1669401000000    0.072188    0.072261
# 4         ETHBTC   ETH   BTC    1669402800000    0.072223    0.072479
# ...          ...   ...   ...              ...         ...         ...
# 1229157  BUSDRON  BUSD   RON    1670943600000    4.629000    4.630000
# 1229158  BUSDRON  BUSD   RON    1670945400000    4.620000    4.631000
# 1229159  BUSDRON  BUSD   RON    1670947200000    4.631000    4.631000
# 1229160  BUSDRON  BUSD   RON    1670949000000    4.630000    4.631000
# 1229161  BUSDRON  BUSD   RON    1670950800000    4.631000    4.631000
#
#          Low price  Close price      Volume  Kline Close time  \
# 0         0.072026     0.072222   1342.1624     1669397399999
# 1         0.072117     0.072162   1185.9640     1669399199999
# 2         0.072101     0.072189    813.4793     1669400999999
# 3         0.072161     0.072212    936.2168     1669402799999
# 4         0.072197     0.072375   1115.5725     1669404599999
# ...            ...          ...         ...               ...
# 1229157   4.620000     4.621000   5984.0000     1670945399999
# 1229158   4.620000     4.630000   3618.0000     1670947199999
# 1229159   4.630000     4.631000   3254.0000     1670948999999
# 1229160   4.630000     4.631000  14415.0000     1670950799999
# 1229161   4.630000     4.631000   3875.0000     1670952599999
#
#          Quote asset volume  Number of trades  Taker buy base asset volume  \
# 0                 96.776126              2657                     794.6663
# 1                 85.640393              2727                     560.9044
# 2                 58.717779              1862                     359.8931
# 3                 67.599402              1816                     470.6928
# 4                 80.727099              3088                     593.4310
# ...                     ...               ...                          ...
# 1229157        27672.337000               108                    2086.0000
# 1229158        16734.982000                42                    1642.0000
# 1229159        15069.018000                33                    2998.0000
# 1229160        66749.027000                92                    7577.0000
# 1229161        17943.045000                52                    1795.0000
#
#          Taker buy quote asset volume  Unused field, ignore
# 0                           57.298344                     0
# 1                           40.508977                     0
# 2                           25.975732                     0
# 3                           33.988586                     0
# 4                           42.945939                     0
# ...                               ...                   ...
# 1229157                   9651.160000                     0
# 1229158                   7593.482000                     0
# 1229159                  13883.738000                     0
# 1229160                  35089.087000                     0
# 1229161                   8312.645000                     0
#
# [1229162 rows x 15 columns]

# %%
uni = pandas.concat([symbols['baseAsset'],symbols['quoteAsset']]).unique() # co 525 loai coin
arr = numpy.concatenate([symbols['baseAsset'],symbols['quoteAsset']])
count = dict()

for i in uni:
    count[i] = numpy.count_nonzero(arr == i)
pandas.Series({k: v for k, v in sorted(count.items(), key=lambda item: item[1],reverse=True)}).head(10)
# 5 loại đồng tiền đầu tiên xuất hiện cực kì nhiều, có thể đây là 5 loại đồng tiền nền của sàn (xuất hiện ở khoảng trên 50% loại đồng, tới khoảng 90%)
# bằng một số tra cứu, BUSD thuộc về đông tiền ổn định, và USDT cố định ở mức 1$, nên ta có thể coi như 3 đồng này là đồng nền chính của sàn
# BTC, ETH, BNB tuy xuất hiện nhiều nhưng giá không ổn định trên thị trường khi quy về tiền thật, nên không thể làm mốc để so sánh được
# Out:
# BTC     437
# USDT    429
# BUSD    390
# BNB     294
# ETH     240
# TRY      79
# EUR      52
# USDC     46
# PAX      40
# TUSD     37
# dtype: int64

# %%
base_coin = ['BUSD','USDT']

# %%
f_symbols =  symbols[symbols.baseAsset.isin(base_coin) | symbols.quoteAsset.isin(base_coin)]
f_symbols = f_symbols[~(f_symbols.baseAsset.isin(base_coin) & f_symbols.quoteAsset.isin(base_coin))]
f_symbols
# Out:
#          symbol   status baseAsset quoteAsset
# 11      BTCUSDT  TRADING       BTC       USDT
# 12      ETHUSDT  TRADING       ETH       USDT
# 98      BNBUSDT  TRADING       BNB       USDT
# 125     BCCUSDT    BREAK       BCC       USDT
# 141     NEOUSDT  TRADING       NEO       USDT
# ...         ...      ...       ...        ...
# 2130   HOOKUSDT  TRADING      HOOK       USDT
# 2131   HOOKBUSD  TRADING      HOOK       BUSD
# 2134  MAGICBUSD  TRADING     MAGIC       BUSD
# 2135  MAGICUSDT  TRADING     MAGIC       USDT
# 2136    BUSDRON  TRADING      BUSD        RON
#
# [817 rows x 4 columns]

# %%
f_data = data[data.Symbol.isin(f_symbols.symbol)]
f_data
# Out:
#           Symbol  base quote  Kline open time  Open price  High price  \
# 8650     BTCUSDT   BTC  USDT    1669395600000   16485.140   16512.430
# 8651     BTCUSDT   BTC  USDT    1669397400000   16483.270   16536.350
# 8652     BTCUSDT   BTC  USDT    1669399200000   16509.520   16528.600
# 8653     BTCUSDT   BTC  USDT    1669401000000   16508.950   16518.590
# 8654     BTCUSDT   BTC  USDT    1669402800000   16495.430   16553.880
# ...          ...   ...   ...              ...         ...         ...
# 1229157  BUSDRON  BUSD   RON    1670943600000       4.629       4.630
# 1229158  BUSDRON  BUSD   RON    1670945400000       4.620       4.631
# 1229159  BUSDRON  BUSD   RON    1670947200000       4.631       4.631
# 1229160  BUSDRON  BUSD   RON    1670949000000       4.630       4.631
# 1229161  BUSDRON  BUSD   RON    1670950800000       4.631       4.631
#
#          Low price  Close price       Volume  Kline Close time  \
# 8650      16474.29    16483.270   3369.76766     1669397399999
# 8651      16482.98    16510.380   3892.49531     1669399199999
# 8652      16502.77    16509.400   2466.67932     1669400999999
# 8653      16477.13    16495.430   2500.32611     1669402799999
# 8654      16494.01    16515.200   2949.47675     1669404599999
# ...            ...          ...          ...               ...
# 1229157       4.62        4.621   5984.00000     1670945399999
# 1229158       4.62        4.630   3618.00000     1670947199999
# 1229159       4.63        4.631   3254.00000     1670948999999
# 1229160       4.63        4.631  14415.00000     1670950799999
# 1229161       4.63        4.631   3875.00000     1670952599999
#
#          Quote asset volume  Number of trades  Taker buy base asset volume  \
# 8650           5.557611e+07             81870                   1723.18461
# 8651           6.427000e+07             91509                   2058.71422
# 8652           4.073370e+07             61263                   1246.75916
# 8653           4.126059e+07             59827                   1169.95110
# 8654           4.872746e+07             66479                   1564.85203
# ...                     ...               ...                          ...
# 1229157        2.767234e+04               108                   2086.00000
# 1229158        1.673498e+04                42                   1642.00000
# 1229159        1.506902e+04                33                   2998.00000
# 1229160        6.674903e+04                92                   7577.00000
# 1229161        1.794304e+04                52                   1795.00000
#
#          Taker buy quote asset volume  Unused field, ignore
# 8650                     2.842171e+07                     0
# 8651                     3.399223e+07                     0
# 8652                     2.058911e+07                     0
# 8653                     1.930727e+07                     0
# 8654                     2.585432e+07                     0
# ...                               ...                   ...
# 1229157                  9.651160e+03                     0
# 1229158                  7.593482e+03                     0
# 1229159                  1.388374e+04                     0
# 1229160                  3.508909e+04                     0
# 1229161                  8.312645e+03                     0
#
# [578316 rows x 15 columns]

# %%
f_data[~f_data.quote.isin(base_coin)] # Các giá trị quy đổi cần điều chỉnh lại
# Out:
#           Symbol  base quote  Kline open time  Open price  High price  \
# 235280   BUSDRUB  BUSD   RUB    1669395600000      60.350      60.360
# 235281   BUSDRUB  BUSD   RUB    1669397400000      60.060      60.140
# 235282   BUSDRUB  BUSD   RUB    1669399200000      60.090      60.400
# 235283   BUSDRUB  BUSD   RUB    1669401000000      60.260      60.310
# 235284   BUSDRUB  BUSD   RUB    1669402800000      60.200      60.240
# ...          ...   ...   ...              ...         ...         ...
# 1229157  BUSDRON  BUSD   RON    1670943600000       4.629       4.630
# 1229158  BUSDRON  BUSD   RON    1670945400000       4.620       4.631
# 1229159  BUSDRON  BUSD   RON    1670947200000       4.631       4.631
# 1229160  BUSDRON  BUSD   RON    1670949000000       4.630       4.631
# 1229161  BUSDRON  BUSD   RON    1670950800000       4.631       4.631
#
#          Low price  Close price   Volume  Kline Close time  \
# 235280       60.02       60.040   5645.0     1669397399999
# 235281       60.01       60.030   1550.0     1669399199999
# 235282       60.01       60.260  58045.0     1669400999999
# 235283       60.16       60.160   1105.0     1669402799999
# 235284       60.15       60.150   2850.0     1669404599999
# ...            ...          ...      ...               ...
# 1229157       4.62        4.621   5984.0     1670945399999
# 1229158       4.62        4.630   3618.0     1670947199999
# 1229159       4.63        4.631   3254.0     1670948999999
# 1229160       4.63        4.631  14415.0     1670950799999
# 1229161       4.63        4.631   3875.0     1670952599999
#
#          Quote asset volume  Number of trades  Taker buy base asset volume  \
# 235280           339840.880                46                        353.0
# 235281            93056.620                10                        230.0
# 235282          3505179.650                37                      57252.0
# 235283            66526.270                13                         87.0
# 235284           171521.070                30                       1128.0
# ...                     ...               ...                          ...
# 1229157           27672.337               108                       2086.0
# 1229158           16734.982                42                       1642.0
# 1229159           15069.018                33                       2998.0
# 1229160           66749.027                92                       7577.0
# 1229161           17943.045                52                       1795.0
#
#          Taker buy quote asset volume  Unused field, ignore
# 235280                      21287.580                     0
# 235281                      13824.880                     0
# 235282                    3457475.550                     0
# 235283                       5243.550                     0
# 235284                      67913.480                     0
# ...                               ...                   ...
# 1229157                      9651.160                     0
# 1229158                      7593.482                     0
# 1229159                     13883.738                     0
# 1229160                     35089.087                     0
# 1229161                      8312.645                     0
#
# [14768 rows x 15 columns]

# %%
# kiểm tra số đồng có trong bảng
print( 'So luong coin co trong data: ', pandas.concat([f_data.base,f_data.quote]).nunique()) # số lượng thấp hơn khi tính ở trên, đó là do một số đồng ko còn hiện hữu nữa
print( 'So luong coin con giao dich: ', pandas.concat([symbols[symbols.status == 'TRADING'].baseAsset ,symbols[symbols.status == 'TRADING'].quoteAsset]).nunique())
# Out:
# So luong coin co trong data:  372
# So luong coin con giao dich:  378

# %% [markdown]
# Với kết quả trên thì công việc lọc ra bảng data cho ra giá trị thực của coin thực sự ổn
